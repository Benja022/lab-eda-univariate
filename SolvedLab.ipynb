# %%
# Importar bibliotecas necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis

# Cargar el conjunto de datos
df = pd.read_csv('amz_uk_price_prediction_dataset.csv')

# Parte 1: Comprender las categorías de productos

# Tablas de frecuencia
category_freq = df['category'].value_counts()
top_5_categories = category_freq.head(5)
print("Top 5 categorías más listadas:")
print(top_5_categories)

# Visualizaciones
plt.figure(figsize=(10, 6))
sns.barplot(x=category_freq.index, y=category_freq.values)
plt.title('Distribución de productos por categoría')
plt.xlabel('Categoría')
plt.ylabel('Frecuencia')
plt.xticks(rotation=90)
plt.show()

# Subconjunto de las principales categorías
top_categories = category_freq.head(5)
plt.figure(figsize=(8, 8))
plt.pie(top_categories.values, labels=top_categories.index, autopct='%1.1f%%', startangle=140)
plt.title('Proporción de las principales categorías de productos')
plt.show()
# Out:
# Top 5 categorías más listadas:
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Name: category, dtype: int64

# %%
# Parte 2: Profundizando en los precios de los productos

# Medidas de centralidad
mean_price = round(df['price'].mean(), 2)
median_price = df['price'].median()
mode_price = df['price'].mode()[0]
print(f"Precio promedio: {mean_price}")
print(f"Precio mediano: {median_price}")
print(f"Precio más común (moda): {mode_price}")

# Medidas de dispersión
variance_price = round(df['price'].var(), 2)
std_dev_price = round(df['price'].std(), 2)
range_price = df['price'].max() - df['price'].min()
iqr_price = df['price'].quantile(0.75) - df['price'].quantile(0.25)
print(f"Varianza del precio: {variance_price}")
print(f"Desviación estándar del precio: {std_dev_price}")
print(f"Rango del precio: {range_price}")
print(f"Rango intercuartílico del precio: {iqr_price}")

# Visualizaciones
plt.figure(figsize=(10, 6))
sns.distplot(df['price'], bins=50, kde=True)
plt.title('Distribución de precios de productos')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['price'])
plt.title('Diagrama de caja de precios de productos')
plt.xlabel('Precio')
plt.show()
# Out:
# Precio promedio: 89.24
# Precio mediano: 19.09
# Precio más común (moda): 9.99
# Varianza del precio: 119445.49
# Desviación estándar del precio: 345.61
# Rango del precio: 100000.0
# Rango intercuartílico del precio: 36.0

# %%
# Verificar las columnas del DataFrame
print(df.columns)
# Out:
# Index(['uid', 'asin', 'title', 'stars', 'reviews', 'price', 'isBestSeller',
#        'boughtInLastMonth', 'category'],
#       dtype='object')

# %%
# Parte 3: Desempaquetando las calificaciones de los productos

# Medidas de centralidad
mean_rating = round(df['stars'].mean(), 2)
median_rating = df['stars'].median()
mode_rating = df['stars'].mode()[0]
print(f"Calificación promedio: {mean_rating}")
print(f"Calificación mediana: {median_rating}")
print(f"Calificación más común (moda): {mode_rating}")

# Medidas de dispersión
variance_rating = round(df['stars'].var(),2)
std_dev_rating = round(df['stars'].std(),2)
iqr_rating = df['stars'].quantile(0.75) - df['stars'].quantile(0.25)
print(f"Varianza de la calificación: {variance_rating}")
print(f"Desviación estándar de la calificación: {std_dev_rating}")
print(f"Rango intercuartílico de la calificación: {iqr_rating}")

# Forma de la distribución
skewness_rating = round(skew(df['stars'].dropna()), 2)
kurtosis_rating = round(kurtosis(df['stars'].dropna()), 2)
print(f"Asimetría de la calificación: {skewness_rating}")
print(f"Curtois de la calificación: {kurtosis_rating}")

# Visualizaciones
plt.figure(figsize=(10, 6))
sns.distplot(df['stars'], bins=50, kde=True)
plt.title('Distribución de calificaciones de productos')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# Calificación promedio: 2.15
# Calificación mediana: 0.0
# Calificación más común (moda): 0.0
# Varianza de la calificación: 4.82
# Desviación estándar de la calificación: 2.19
# Rango intercuartílico de la calificación: 4.4
# Asimetría de la calificación: 0.08
# Curtois de la calificación: -1.93
